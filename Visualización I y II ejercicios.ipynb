# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Cargar dataset Iris

df = pd.read_csv('merchant_fill_nonulls.csv')
df.head()
# Out:
#    Unnamed: 0                                              title  price  \
# 0           0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00
# 1           1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00
# 2           2  Nouvelle mode d'été femmes robe décontractée c...   4.90
# 3           3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93
# 4           4  Nouvelle mode d'été femmes robe décontractée c...   5.65
#
#    retail_price  units_sold uses_ad_boosts  rating_sold  rating_count  \
# 0            14         100             No         3.76            54
# 1            22       20000             Si         3.45          6135
# 2             8        1000             Si         3.83            99
# 3             6         100             No         3.77            47
# 4            10         100             Si         2.86             7
#
#   badge_local_product badge_product_quality  ... mean_product_prices  \
# ...

# %% [markdown]
# 1. ¿Cómo se distribuyen los precios de los productos?

# %%
sns.histplot(df['price'], bins = 30);

# %% [markdown]
# 2. ¿Cuál es la relación entre el precio y la calificación promedio de los productos?

# %%
sns.scatterplot(x='price', y='rating_count', data=df);

# %%
sns.scatterplot(x = 'price', y = 'rating_sold', data = df);
#Podríamos decir que la correlación que hay es que los productos más baratos se compran más por lo tanto tienen más reseñas.

# %% [markdown]
# 3. ¿Cómo se distribuyen los precios de los productos en función de si se utilizan anuncios promocionales (uses_ad_boosts) o no?

# %%
sns.boxplot(x='price', y='uses_ad_boosts', data=df);

# %%
sns.scatterplot(x = 'price', y = 'uses_ad_boosts', data = df);
